# %%
import pandas as pd
movies = pd.read_csv('fandango_score_comparison.csv')
movies
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies['Metacritic_norm_round'].hist()

# %%
movies['Fandango_Stars'].hist()

# %%
#the differences that can be observed are that the fandango stars data has more gaps in intervals whereas the metacritic norm round has tighter intervals with only a gap from 2-2.5
#we can also observe the interval difference with fandango at 3-5 while metacritic is 0-4.5

# %%
movies['Metacritic_norm_round'].mean()
# Out:
# 2.9726027397260273

# %%
movies['Fandango_Stars'].mean()
# Out:
# 4.089041095890411

# %%
movies['Metacritic_norm_round'].median()
# Out:
# 3.0

# %%
movies['Fandango_Stars'].median()
# Out:
# 4.0

# %%
import numpy as np

# %%
np.std(movies['Fandango_Stars'])
# Out:
# 0.5385321612699531

# %%
np.std(movies['Metacritic_norm_round'])
# Out:
# 0.9875610297038631

# %%
#we can see that Metacritic has a basic weighted average forumula being pulled from various sources in order to calculate ratings
#the Fandango methodology isn't very clear, and reveals that it is a subsidiary of NBC and doesn't give any movie below a 3 star rating

# %%
#the median for metacritic is higher because of the few low values dragging down the median
#the median for fandango is lower because of the few high ratings inflating the average

# %%
#the fandango stdev is lower because the interval range is smaller from 3-5 compared to the higher stdev of metacritic which go from 0-5

# %%
#the mean for fandango stars is higher due to the inflated values and external relations the company has with movie studios

# %%
plt.scatter(movies['Metacritic_norm_round'],movies['Fandango_Stars'])

# %%
movies['fm_diff'] = np.abs(movies['Metacritic_norm_round'] - movies['Fandango_Stars'])

# %%
movies.sort_values(by='fm_diff', ascending=False)
# Out:
#                                                 FILM  RottenTomatoes  \
# 3                             Do You Believe? (2015)              18
# 85                                 Little Boy (2015)              20
# 47                                      Annie (2014)              27
# 19                                     Pixels (2015)              17
# 134                          The Longest Ride (2015)              31
# 133                    Paul Blart: Mall Cop 2 (2015)               5
# 35                                   The Loft (2015)              11
# 15                                    Taken 3 (2015)               9
# 125                        The Wedding Ringer (2015)              27
# 51                                  Entourage (2015)              32
# 98                                   Get Hard (2015)              29
# 46            The Divergent Series: Insurgent (2015)              30
# 33                          The Boy Next Door (2015)              10
# ...

# %%
from scipy.stats import pearsonr

r_value, p_value = pearsonr(movies['Fandango_Stars'], movies['Metacritic_norm_round'])
r_value
# Out:
# 0.17844919073895918

# %%
from scipy.stats import linregress

slope, intercept,r_value,p_value,stderr_slope = linregress(movies['Metacritic_norm_round'],movies['Fandango_Stars'])

# %%
pred_3 = 3*slope+intercept
pred_3
# Out:
# 4.091707152821204

# %%
pred_1 = 1*slope + intercept
pred_5 = 5*slope + intercept
plt.scatter(movies['Metacritic_norm_round'],movies['Fandango_Stars'])
plt.plot([1,5],[pred_1,pred_5])
plt.xlim(1,5)
plt.show()

# %%
from scipy.stats import pearsonr

r_value, p_value = pearsonr(movies['RT_norm_round'], movies['Metacritic_norm_round'])
r_value
# Out:
# 0.9466002019530929

# %%
#this adds to the speculation of bias in Fandango as we can see rotten tomatoes and metacritic have a high positive correlation indicating a similarity in both scores

# %%
movies['user_critic_diff'] = np.abs(movies['RT_norm_round'] - movies['RT_user_norm_round'])

# %%
movies.sort_values(by='user_critic_diff',ascending=False)
# Out:
#                                                   FILM  RottenTomatoes  \
# 3                               Do You Believe? (2015)              18
# 85                                   Little Boy (2015)              20
# 105                            Hitman: Agent 47 (2015)               7
# 125                          The Wedding Ringer (2015)              27
# 51                                    Entourage (2015)              32
# 15                                      Taken 3 (2015)               9
# 134                            The Longest Ride (2015)              31
# 69                                   Mr. Turner (2014)              98
# 103                               Strange Magic (2015)              17
# 83                                    Self/less (2015)              20
# 78                                      Chappie (2015)              30
# 33                            The Boy Next Door (2015)              10
# ...

# %%
np.count_nonzero(movies['user_critic_diff'])
# Out:
# 111

# %%
#out of the 146 movies 111 had a disparity in value with user and critic values differing
